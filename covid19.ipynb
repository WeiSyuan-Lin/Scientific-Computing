# %%
import pandas
import os
Folder_Path = r'C:\Users\nightrain\Desktop'
data = pandas.read_csv(Folder_Path+'\\'+'covid19.csv')

# %%
#help(data)
data.columns
# Out:
# Index(['date', 'country_name', 'new_confirmed', 'new_deceased',
#        'new_recovered', 'new_tested', 'new_hospitalized_patients',
#        'new_intensive_care_patients', 'new_ventilator_patients',
#        'mobility_transit_stations', 'mobility_retail_and_recreation',
#        'mobility_grocery_and_pharmacy', 'mobility_parks',
#        'mobility_residential', 'mobility_workplaces', 'latitude', 'longitude',
#        'average_temperature_celsius', 'minimum_temperature_celsius',
#        'maximum_temperature_celsius', 'rainfall_mm', 'snowfall_mm'],
#       dtype='object')

# %%
Data=data[['date', 'country_name', 'new_confirmed', 'new_deceased',
       'new_recovered', 'new_tested', 
       'latitude', 'longitude',
       'average_temperature_celsius', 'minimum_temperature_celsius',
       'maximum_temperature_celsius', 'rainfall_mm']]

# %%
Data=Data.dropna()

# %%
Data
# Out:
#                date              country_name  new_confirmed  new_deceased  \
# 0        2020-07-24  United States of America           10.0           0.0
# 1        2020-08-01  United States of America           15.0           0.0
# 2        2020-08-07  United States of America            3.0           0.0
# 4271     2020-08-06  United States of America           20.0           0.0
# 5561     2020-04-24  United States of America           18.0           0.0
# ...             ...                       ...            ...           ...
# 2736420  2020-04-28  United States of America            3.0           0.0
# 2736421  2020-05-02  United States of America            0.0           0.0
# 2736422  2020-05-14  United States of America            0.0           0.0
# 2736423  2020-07-14  United States of America           26.0           0.0
# 2736424  2020-07-18  United States of America           14.0           0.0
#
#          new_recovered  new_tested   latitude   longitude  \
# ...
